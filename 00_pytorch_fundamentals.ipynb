# %% [markdown]
# <a href="https://colab.research.google.com/github/SDRajvardhan/DL-with-Pytorch/blob/main/00_pytorch_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pytorch Fundamentals

# %%
print("I am excited to learn pytorch")
# Out:
# I am excited to learn pytorch
